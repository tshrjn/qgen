# %%
# %run main.py --no_eval --train_data "/home/ra2630/NLU/train-v1.1.json" --gpu --tf_ratio 0.2 --gen --attention
# Out:
# Namespace(attention=True, batch_size=32, example_to_train=1000, gen=True, gpu=True, hidden_size=300, load='', load_data='', lr=0.0003, no_eval=True, no_train=False, num_epochs=100, reduced_glove=False, save='', save_data='', seed=42, split_ratio=0.8, tf_ratio=0.2, train_data='/home/ra2630/NLU/train-v1.1.json', words_to_take=2000)
# No. of invalid words/examples: 4858
# Number of batches =  32
# No. of batches in training data: 25, with batch_size: 32
# Batch: 0 	 Epoch : 0	Net Loss: 7.5097 	Answer Loss: 0.6766 	Question Loss: 7.5097
# Batch: 1 	 Epoch : 0	Net Loss: 7.3305 	Answer Loss: 0.6766 	Question Loss: 7.3305
# Batch: 2 	 Epoch : 0	Net Loss: 7.1516 	Answer Loss: 0.6766 	Question Loss: 7.1516
# Batch: 3 	 Epoch : 0	Net Loss: 6.9731 	Answer Loss: 0.6766 	Question Loss: 6.9731
# Batch: 4 	 Epoch : 0	Net Loss: 6.7949 	Answer Loss: 0.6766 	Question Loss: 6.7949
# Batch: 5 	 Epoch : 0	Net Loss: 6.6172 	Answer Loss: 0.6766 	Question Loss: 6.6172
# ...

# %%
from models import Attention

# %%
Attention(100,100, 0.1)

# %%
# !hostname

# %%
# %tb
